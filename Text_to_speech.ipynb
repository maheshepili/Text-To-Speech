# %%
# !pip install gTTS #Python library that sends your text to Google's free TTS API
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
# ...

# %%
from gtts import gTTS
# "hi" for Hindi, "gu" for Gujarati, "fr" for French.
tts = gTTS("hello, माझा नाव क्रिनल आहे", lang="mr") #'en' is language code for English. and ''mr' is for Marathi
# tts = gTTS("ಕನ್ನಡವೇ ಸತ್ಯ ಕನ್ನಡವೇ ನಿತ್ಯ", lang="kn") # "Hello, how are you?" in Russian
tts.save("output.mp3")

from IPython.display import Audio
Audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
